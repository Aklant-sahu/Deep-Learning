# %%
import  numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import tensorflow as tf

# %%
x=np.random.randn(200)

# %%
sns.scatterplot(range(200),x)

# %%
y=1*x+1+np.random.normal(0,20,200)

# %%
sns.scatterplot(range(200),y)

# %%
x=np.random.randn(200)

# %%
x=range

# %%
sns.scatterplot(range(200),range(200))

# %%
x_pt=[]
y_pt=[]

# %%
for i in range(1000):
    x=np.random.normal(0,0.5)
    y=0.3*x+0.7+np.random.normal(0,0.1)
    x_pt.append(x)
    y_pt.append(y)

# %%
df=pd.DataFrame(data=zip(x_pt,y_pt),columns=['x','y'])

# %%
df
# Out:
#             x         y
# 0   -0.855514  0.520849
# 1    0.019194  0.716328
# 2    0.212955  0.885193
# 3   -0.189132  0.762334
# 4   -0.362182  0.639241
# ..        ...       ...
# 995 -0.143053  0.654076
# 996  0.159430  0.660642
# 997  0.258293  0.723946
# 998 -0.268131  0.592384
# 999 -0.743485  0.290749
#
# [1000 rows x 2 columns]

# %%
df=df[['x','y']].sort_values(by='x')

# %%
df=df.reset_index().drop('index',axis=1)

# %%
df
# Out:
#             x         y
# 0   -1.478001  0.205438
# 1   -1.474448  0.242917
# 2   -1.472770  0.180363
# 3   -1.460092  0.224538
# 4   -1.326649  0.294560
# ..        ...       ...
# 995  1.242788  1.157118
# 996  1.247745  1.060811
# 997  1.379306  1.234216
# 998  1.503392  1.333257
# 999  1.680749  1.219129
#
# [1000 rows x 2 columns]

# %%
perfect_fit=[]
for i in range(1000):
    pt=y

# %%
sns.scatterplot(x_pt,y_pt)
